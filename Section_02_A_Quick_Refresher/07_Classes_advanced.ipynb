# %% [markdown]
# # Advanced Practice Problems: Python Custom Classes
#
# This notebook contains advanced problems **with full solutions** based on Python custom classes.
#
# Topics covered:
# - `class` and `__init__`
# - instance attributes and methods
# - `__str__`, `__repr__`
# - operator overloading (`__eq__`, `__lt__`, `__add__`)
# - `@property` and validation
# - sorting objects
# - class design best practices

# %% [markdown]
# ---
# ## Problem 1 — Build a Robust Rectangle Class
#
# Create a `Rectangle` class with:
# - width and height validation (> 0)
# - `area()`
# - `perimeter()`
# - readable `__str__`
# - official `__repr__`

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    @property
    def width(self):
        return self._width

    @width.setter
    def width(self, value):
        if value <= 0:
            raise ValueError('Width must be positive')
        self._width = value

    @property
    def height(self):
        return self._height

    @height.setter
    def height(self, value):
        if value <= 0:
            raise ValueError('Height must be positive')
        self._height = value

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height)

    def __str__(self):
        return f'Rectangle: {self.width} x {self.height}'

    def __repr__(self):
        return f'Rectangle({self.width}, {self.height})'


r = Rectangle(10, 5)
print(r)
print(repr(r))
print(r.area())
print(r.perimeter())
# Out:
# Rectangle: 10 x 5
# Rectangle(10, 5)
# 50
# 30

# %% [markdown]
# ---
# ## Problem 2 — Equality Based on Dimensions
#
# Two rectangles are equal if width and height match.

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def __eq__(self, other):
        if not isinstance(other, Rectangle):
            return False
        return self.width == other.width and self.height == other.height


r1 = Rectangle(4, 6)
r2 = Rectangle(4, 6)
r3 = Rectangle(2, 3)

print(r1 == r2)
print(r1 == r3)
# Out:
# True
# False

# %% [markdown]
# ---
# ## Problem 3 — Compare Rectangles by Area
#
# Implement `<` so rectangles compare using area.

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def __lt__(self, other):
        if not isinstance(other, Rectangle):
            return NotImplemented
        return self.area() < other.area()


r1 = Rectangle(2, 10)
r2 = Rectangle(5, 5)

print(r1 < r2)
print(r2 < r1)
# Out:
# True
# False

# %% [markdown]
# ---
# ## Problem 4 — Add Rectangles
#
# Define `+` so adding rectangles returns a new rectangle:
# - width = sum of widths
# - height = sum of heights

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def __add__(self, other):
        if not isinstance(other, Rectangle):
            return NotImplemented
        return Rectangle(self.width + other.width,
                         self.height + other.height)

    def __repr__(self):
        return f'Rectangle({self.width}, {self.height})'


r1 = Rectangle(2, 3)
r2 = Rectangle(4, 5)
print(r1 + r2)
# Out:
# Rectangle(6, 8)

# %% [markdown]
# ---
# ## Problem 5 — Immutable Temperature Class
#
# Create a class `Temperature` storing Celsius.
#
# Requirements:
# - read-only `celsius`
# - computed property `fahrenheit`
# - nice string output

# %%
class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius

    @property
    def celsius(self):
        return self._celsius

    @property
    def fahrenheit(self):
        return self.celsius * 9/5 + 32

    def __str__(self):
        return f'{self.celsius}°C / {self.fahrenheit:.1f}°F'


t = Temperature(25)
print(t)
print(t.fahrenheit)
# Out:
# 25°C / 77.0°F
# 77.0

# %% [markdown]
# ---
# ## Problem 6 — Bank Account with Validation
#
# Build a `BankAccount` class:
# - owner
# - balance starts at 0
# - deposit(amount)
# - withdraw(amount)
# - cannot overdraw

# %%
class BankAccount:
    def __init__(self, owner):
        self.owner = owner
        self.balance = 0

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError('Deposit must be positive')
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            raise ValueError('Insufficient funds')
        self.balance -= amount

    def __str__(self):
        return f'{self.owner}: ${self.balance}'


acc = BankAccount('Alice')
acc.deposit(500)
acc.withdraw(120)
print(acc)
# Out:
# Alice: $380

# %% [markdown]
# ---
# ## Problem 7 — Sort Custom Objects
#
# Create a `Student` class sortable by GPA.

# %%
class Student:
    def __init__(self, name, gpa):
        self.name = name
        self.gpa = gpa

    def __lt__(self, other):
        return self.gpa < other.gpa

    def __repr__(self):
        return f'{self.name} ({self.gpa})'


students = [
    Student('Ana', 3.4),
    Student('Bob', 3.9),
    Student('Cara', 3.2)
]

print(sorted(students))
# Out:
# [Cara (3.2), Ana (3.4), Bob (3.9)]

# %% [markdown]
# ---
# ## Problem 8 — Class Variable vs Instance Variable
#
# Track how many `Car` objects were created.

# %%
class Car:
    total_created = 0

    def __init__(self, brand):
        self.brand = brand
        Car.total_created += 1


c1 = Car('Toyota')
c2 = Car('BMW')
c3 = Car('Audi')

print(Car.total_created)
# Out:
# 3

# %% [markdown]
# ---
# ## Problem 9 — Make Objects Callable
#
# Implement `__call__` so object behaves like function.

# %%
class Multiplier:
    def __init__(self, factor):
        self.factor = factor

    def __call__(self, value):
        return value * self.factor


double = Multiplier(2)
triple = Multiplier(3)

print(double(10))
print(triple(10))
# Out:
# 20
# 30

# %% [markdown]
# ---
# ## Problem 10 — Mini Inventory System (Advanced)
#
# Design `Product` class:
# - name
# - price (>0)
# - quantity (>=0)
# - total_value property

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    @property
    def price(self):
        return self._price

    @price.setter
    def price(self, value):
        if value <= 0:
            raise ValueError('Price must be positive')
        self._price = value

    @property
    def quantity(self):
        return self._quantity

    @quantity.setter
    def quantity(self, value):
        if value < 0:
            raise ValueError('Quantity cannot be negative')
        self._quantity = value

    @property
    def total_value(self):
        return self.price * self.quantity

    def __repr__(self):
        return f'{self.name}: ${self.price} x {self.quantity}'


p = Product('Laptop', 1500, 4)
print(p)
print(p.total_value)
# Out:
# Laptop: $1500 x 4
# 6000

# %% [markdown]
# ---
# # Final Notes
#
# Best practices used in these solutions:
# - Validate data early
# - Use properties for controlled access
# - Use special methods for Pythonic behavior
# - Keep classes focused and readable
# - Return `NotImplemented` for unsupported operators
