# %% [markdown]
# ### Default Values - Beware!

# %%
# from datetime import datetime
import datetime

# %%
# print(datetime.datetime.now(datetime.UTC)())
print(datetime.datetime.now(datetime.UTC))
# Out:
# 2026-05-10 12:24:22.678353+00:00

# %%
def log(msg, *, dt=datetime.datetime.now(datetime.UTC)):
    print('{0}: {1}'.format(dt, msg))

# %%
log('message 1')
# Out:
# 2026-05-10 12:24:23.298214+00:00: message 1

# %%
log('message 2', dt='2001-01-01 00:00:00')
# Out:
# 2001-01-01 00:00:00: message 2

# %%
log('message 3')
# Out:
# 2026-05-10 12:24:23.298214+00:00: message 3

# %%
log('message 4')
# Out:
# 2026-05-10 12:24:23.298214+00:00: message 4

# %% [markdown]
# As you can see, the default for **dt** is calculated when the function is **defined** and is **NOT** re-evaluated when the function is called.

# %% [markdown]
# #### Solution Pattern

# %% [markdown]
# Here is one pattern we can use to achieve the desired result:
#
# We actually set the default to None - this makes the argument optional, and we can then test for None **inside** the function and default to the current time if it is None.

# %%
def log(msg, *, dt=None):
    dt = dt or datetime.datetime.now(datetime.UTC)
    # above is equivalent to:
    #if not dt:
    #    dt = datetime.datetime.now(datetime.UTC)()
    print('{0}: {1}'.format(dt, msg))

# %%
log('message 1')
# Out:
# 2026-05-10 12:24:32.642579+00:00: message 1

# %%
log('message 2')
# Out:
# 2026-05-10 12:24:34.567362+00:00: message 2

# %%
log('message 3', dt='2001-01-01 00:00:00')
# Out:
# 2001-01-01 00:00:00: message 3

# %%
log('message 4')
# Out:
# 2026-05-10 12:24:39.208225+00:00: message 4
