# %% [markdown]
# ### Decorators Application (Timing)

# %% [markdown]
# Here we go back to an example we have seen in the past - timing how long it takes to run a certain function.

# %%
def timed(fn):
    from time import perf_counter
    from functools import wraps
    
    @wraps(fn)
    def inner(*args, **kwargs):
        start = perf_counter()
        result = fn(*args, **kwargs)
        end = perf_counter()
        elapsed = end - start
        
        args_ = [str(a) for a in args]
        kwargs_ = ['{0}={1}'.format(k, v) for (k, v) in kwargs.items()]
        all_args = args_ + kwargs_
        args_str = ','.join(all_args)
        print('{0}({1}) took {2:.6f}s to run.'.format(fn.__name__, 
                                                         args_str,
                                                         elapsed))
        return result
    
    return inner

# %% [markdown]
# Let's write a function that calculates the n-th Fibonacci number:
#
# `1, 1, 2, 3, 5, 8, ...`
#
# We will implement this using three different methods:
# 1. recursion
# 2. a loop
# 3. functional programming (reduce)
#
# We use a 1-based system, e.g. first Fibonnaci number has index 1, etc.

# %% [markdown]
# #### Using Recursion

# %%
def calc_recursive_fib(n):
    if n <=2:
        return 1
    else:
        return calc_recursive_fib(n-1) + calc_recursive_fib(n-2)

# %%
calc_recursive_fib(3)
# Out:
# 2

# %%
calc_recursive_fib(6)
# Out:
# 8

# %%
@timed
def fib_recursed(n):
    return calc_recursive_fib(n)

# %%
fib_recursed(33)
# Out:
# fib_recursed(33) took 0.428454s to run.
# 3524578

# %%
fib_recursed(34)
# Out:
# fib_recursed(34) took 0.658983s to run.
# 5702887

# %%
fib_recursed(35)
# Out:
# fib_recursed(35) took 1.157869s to run.
# 9227465

# %% [markdown]
# There's a reason we did not decorate our recursive function directly!

# %%
@timed
def fib_recursed_2(n):
    if n <=2:
        return 1
    else:
        return fib_recursed_2(n-1) + fib_recursed_2(n-2)

# %%
fib_recursed_2(10)
# Out:
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000001s to run.
# fib_recursed_2(3) took 0.000108s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000140s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000024s to run.
# fib_recursed_2(5) took 0.000200s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000021s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000048s to run.
# fib_recursed_2(6) took 0.000277s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000022s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000045s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000022s to run.
# fib_recursed_2(5) took 0.000091s to run.
# fib_recursed_2(7) took 0.000391s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000024s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000045s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000020s to run.
# fib_recursed_2(5) took 0.000096s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000023s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000048s to run.
# fib_recursed_2(6) took 0.000166s to run.
# fib_recursed_2(8) took 0.000579s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000026s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000051s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000027s to run.
# fib_recursed_2(5) took 0.000104s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000001s to run.
# fib_recursed_2(3) took 0.000025s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000048s to run.
# fib_recursed_2(6) took 0.000181s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000024s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000052s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000001s to run.
# fib_recursed_2(3) took 0.000090s to run.
# fib_recursed_2(5) took 0.000483s to run.
# fib_recursed_2(7) took 0.000698s to run.
# fib_recursed_2(9) took 0.001313s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000046s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000094s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000054s to run.
# fib_recursed_2(5) took 0.000200s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000030s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000063s to run.
# fib_recursed_2(6) took 0.000297s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000001s to run.
# fib_recursed_2(3) took 0.000031s to run.
# fib_recursed_2(2) took 0.000001s to run.
# fib_recursed_2(4) took 0.000065s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000030s to run.
# fib_recursed_2(5) took 0.000128s to run.
# fib_recursed_2(7) took 0.000460s to run.
# fib_recursed_2(2) took 0.000001s to run.
# fib_recursed_2(1) took 0.000001s to run.
# fib_recursed_2(3) took 0.000062s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000129s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000031s to run.
# fib_recursed_2(5) took 0.000193s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(1) took 0.000000s to run.
# fib_recursed_2(3) took 0.000031s to run.
# fib_recursed_2(2) took 0.000000s to run.
# fib_recursed_2(4) took 0.000062s to run.
# fib_recursed_2(6) took 0.000287s to run.
# fib_recursed_2(8) took 0.000784s to run.
# fib_recursed_2(10) took 0.002134s to run.
# 55

# %% [markdown]
# Since we are calling the function recursively, we are actually calling the **decorated** function recursively. In this case I wanted the total time to calculate the n-th number, not the time for each recursion.
#
# You will notice from the above how inefficient the recursive method is: the same fibonacci numbers are calculated repeatedly! This is why as the value of `n` start increasing beyond 30 we start seeing considerable slow downs.

# %% [markdown]
# #### Using a Loop

# %%
@timed
def fib_loop(n):
    fib_1 = 1
    fib_2 = 1
    for i in range(3, n+1):
        fib_1, fib_2 = fib_2, fib_1 + fib_2
    return fib_2

# %%
fib_loop(3)
# Out:
# fib_loop(3) took 0.000006s to run.
# 2

# %%
fib_loop(6)
# Out:
# fib_loop(6) took 0.000005s to run.
# 8

# %%
fib_loop(34)
# Out:
# fib_loop(34) took 0.000006s to run.
# 5702887

# %%
fib_loop(35)
# Out:
# fib_loop(35) took 0.000009s to run.
# 9227465

# %% [markdown]
# As you can see this method is much more efficient!

# %% [markdown]
# #### Using  Reduce

# %% [markdown]
# We first need to understand how we are going to calculate the Fibonnaci sequence using reduce:
#
# <pre>
# n=1:
# (1, 0) --> (1, 1)
#
# n=2:
# (1, 0) --> (1, 1) --> (1 + 1, 1) = (2, 1)  : result = 2
#
# n=3
# (1, 0) --> (1, 1) --> (2, 1) --> (2+1, 2) = (3, 2)  : result = 3
#
# n=4
# (1, 0) --> (1, 1) --> (2, 1) --> (3, 2) --> (5, 3)  : result = 5
# </pre>
#
# In general each step in the reduction is as follows:
#
# <pre>
# previous value = (a, b)
# new value = (a+b, a)
# </pre>
#
# If we start our reduction with an initial value of `(1, 0)`, we need to run our "loop" n times.
#
# We therefore use a "dummy" sequence of length `n` to create `n` steps in our reduce.

# %%
from functools import reduce

@timed
def fib_reduce(n):
    initial = (1, 0)
    dummy = range(n-1)
    fib_n = reduce(lambda prev, n: (prev[0] + prev[1], prev[0]), 
                   dummy, 
                   initial)
    return fib_n[0]

# %%
fib_reduce(3)
# Out:
# fib_reduce(3) took 0.000007s to run.
# 2

# %%
fib_reduce(6)
# Out:
# fib_reduce(6) took 0.000011s to run.
# 8

# %%
fib_reduce(34)
# Out:
# fib_reduce(34) took 0.000011s to run.
# 5702887

# %%
fib_reduce(35)
# Out:
# fib_reduce(35) took 0.000013s to run.
# 9227465

# %% [markdown]
# Now we can run a quick comparison between the various timed implementations:

# %%
fib_recursed(35)
fib_loop(35)
fib_reduce(35)
# Out:
# fib_recursed(35) took 1.016177s to run.
# fib_loop(35) took 0.000007s to run.
# fib_reduce(35) took 0.000017s to run.
# 9227465

# %% [markdown]
# Even though the recursive algorithm is by far the easiest to understand, it is also the slowest. We'll see how to fix this in an upcoming video using a technique called **memoization**.

# %% [markdown]
# First let's focus on the loop and reduce variants. Our timing is not very effective since we only time a single calculation for each - there could be some variance if we run these tests multiple times:

# %%
for i in range(10):
    result =  fib_loop(10000)
# Out:
# fib_loop(10000) took 0.004429s to run.
# fib_loop(10000) took 0.003846s to run.
# fib_loop(10000) took 0.003019s to run.
# fib_loop(10000) took 0.002237s to run.
# fib_loop(10000) took 0.002102s to run.
# fib_loop(10000) took 0.001954s to run.
# fib_loop(10000) took 0.002822s to run.
# fib_loop(10000) took 0.002865s to run.
# fib_loop(10000) took 0.003659s to run.
# fib_loop(10000) took 0.002781s to run.

# %%
for i in range(10):
    result = fib_reduce(10000)
# Out:
# fib_reduce(10000) took 0.010048s to run.
# fib_reduce(10000) took 0.003416s to run.
# fib_reduce(10000) took 0.002848s to run.
# fib_reduce(10000) took 0.002395s to run.
# fib_reduce(10000) took 0.013191s to run.
# fib_reduce(10000) took 0.006577s to run.
# fib_reduce(10000) took 0.006879s to run.
# fib_reduce(10000) took 0.004039s to run.
# fib_reduce(10000) took 0.003808s to run.
# fib_reduce(10000) took 0.003971s to run.

# %% [markdown]
# In general it is better to time the same function call multiple times and generate and average of the run times.
#
# We'll see in an upcoming video how we can do this from within our decorator.

# %% [markdown]
# In the meantime observe that the simple loop approach seems to perform about twice as fast as the reduce approach!!
#
# The moral of this side note is that simply because you **can** do something in  Python using some fancy or cool technique does not mean you **should**!

# %% [markdown]
# We technically could write our reduce-based function as a one liner:

# %%
from functools import reduce 

fib_1 = timed(lambda n: reduce(lambda prev, n: (prev[0] + prev[1], prev[0]),
                               range(n), 
                               (0, 1))[0])

# %%
fib_loop(100)
# Out:
# fib_loop(100) took 0.000015s to run.
# 354224848179261915075

# %%
fib_1(100)
# Out:
# <lambda>(100) took 0.000050s to run.
# 354224848179261915075

# %% [markdown]
# So yes, it's cool that you can write this using a single line of code, but consider two things here:
# 1. Is it as efficient as another method?
# 2. Is the code **readable**?
#
# Code readability is something I cannot emphasize enough. Given similar efficiencies (cpu / memory), give preference to code that is more easily understandable!
#
# Sometimes, if the efficiency is not greatly impacted (or does not matter in absolute terms), I might even give preference to less efficient, but more readable (i.e. understanbdable), code.
#
# But enough of the soapbox already :-)
